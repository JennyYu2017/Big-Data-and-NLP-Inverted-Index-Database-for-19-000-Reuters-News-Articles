# %% [markdown]
# **Big Data and NLP: Inverted Index Database for 19,000 Reuters News Articles**
#
# This project is about implementing an inverted index using Apache Spark（Pyspark）to build a relational database (SQLite) for 19,000 Reuters News Articles.
#
# Jenny Yu

# %%
# Set up the environment

# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz
# !pip install -q findspark

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

import findspark 
findspark.init("spark-2.4.4-bin-hadoop2.7")# SPARK_HOME

from pyspark import SparkContext
sc = SparkContext.getOrCreate()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Put input_docs.zip in Google Drive

# !rm -rf input_docs

# !cp /content/drive/My\ Drive/input_docs.zip .
# !unzip input_docs.zip > /dev/null

# !cp /content/drive/My\ Drive/input_docs_sample.zip .
# !unzip input_docs_sample.zip > /dev/null

# !ls input_docs/ | wc -l

# for the real collection change above input_docs_sample.zip to input_docs.zip
# for the sample collection of 5 docs, the process is fast
# for the real collection, the process takes about 6 min (start to finish, the whole notebook)
# Out:
# 19026

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# **1.Build the index using a document collection**
#
# **Create an RDD from a text file**
#
# Each line of the text file becomes an element of the RDD.

# %%
# wholeTextFiles generates an RDD of pair values, 
# where the key is the full path of each file, the value is the content of each file
# input = sc.wholeTextFiles("/content/drive/My\ Drive/input_docs");
input = sc.wholeTextFiles("input_docs");

# Now we strip the prefix of filenames and leave only the basename. 
# e.g. 'file:/content/drive/My Drive/Colab Notebooks/data_spark/input_docs/3.html'
# becomes '3.html' 
import os
from bs4 import BeautifulSoup

input2 = input.map(lambda x: (int(os.path.basename(x[0]).split(".")[0]), x[1]))

print(input2.take(1))
# Out:
# [(14372, "<H2> 7-APR-1987 12:42:50.60</H2>\r\n<H2>COCOA/COFFEE/SUGAR TRADE NEWS/MARKET COMMENT</H2>\r\nWest African\norigins believed near market, especially Ivory and Ghana. Ivory\nreported traded yesterday around 1,325 French Francs per 100\nkilos cif for new crop while Ghana was offering at 1,460 stg a\ntonne cif, also for new crop... Offtake small, restricted to\ndealer book-squaring ahead of buffer stock buying which\npossibly next week, some say... Ghana resale June/Aug 60 stg\nover Sep.\n    Cocoa comment/market talk - Terminal on defensive on firm\nsterling and overhanging West African new crop offers, but\nprospective buffer stock buying and lower Bahia Temperao crop\n(possibly down to 1.5 mln bags from 2.0/2.5 mln) constructive.\n    Sugar physical trade - Malta tendering for 3,000 tonnes\nwhites today for arrival in two equal parts in May and June. No\nnews by late afternoon... India in tomorrow for one/two cargoes\nwhites with Syria tendering same day for 36,000 tonnes whites\nfor June/July/Aug shipment... EC export tender tomorrow but\nafter last week's heavy authorised exports (102,350 tonnes) at\nthe highest ever-rebate of 46.864 Ecus per 100 kilos, and with\nmove to intervention of near 800,000 tonnes, tomorrow's result\nis anybody's guess, traders said... Pakistan tendering\nSaturday.\n    Sugar comment/market talk - Afternoon terminal rally after\nfall which had been linked to lack of Soviet/Chinese offtake.\n    Coffee physical market - Origin offers scarce and roaster\ndemand quieted down... Roasters may be adequately covered for\ntime being after Brazilian, Colombian and Mexican sales over\nthe past week.\n    Coffee market talk and comment - Futures quietly firmer,\nbut trade featureless. Prices seem to be consolidating at\ncurrent levels following recent declines, but will need further\nsigns of demand to sustain support, dealers said... With Brazil\nMay registrations out of the way, market is awaiting fresh\nfundamental news to provide direction.\n \n ")]

# %% [markdown]
# **Clean the text**
#
# **Create RDD of （word，（docid，frqc，tf））**

# %%
# Doc to wordlist function
# The output will be a list of tuples such as 
# ("apple", (3,10,10/20)), 
# where 3 is docid, 
# 10 is frequency of "apple" in this doc, 
# 20 is maxf in in this doc.

# from bs4 import BeautifulSoup
from collections import Counter
import re

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# for a given doc return a list of tuples of the form (w, (docid, freq, freq/maxfreq))
def dw(docid, htmltext):
  cleantext = BeautifulSoup(htmltext).get_text().lower()

  #returning result
  tokenizedText = re.findall(r"\b[a-z]+\b",cleantext)
  filteredToken = [w for w in tokenizedText if not w in stop_words]
  tokenCnt = Counter(filteredToken)
  maxf = tokenCnt.most_common(1)[0][1]

  wdft = dict()
  for t in filteredToken:
    frqc = tokenCnt[t]
    wdft[t] = (docid,frqc,frqc/maxf)
  return wdft

word_docid_freq_tf = input2.flatMap(lambda x: [(t,dw(x[0],x[1])[t]) for t in dw(x[0],x[1])])

# %% [markdown]
# **Create RDD of (word, (did,freq,tfidf) ）**

# %%
# Now create an RDD as follows 
# (word, [(did1,freq1,tf1), (did2,freq2,tf2), ...])
		    
word_postinglist_freq_tf = word_docid_freq_tf.groupByKey()

# %%
from pyspark.accumulators import AccumulatorParam
class ListParam(AccumulatorParam):
    def zero(self, v):
        return []
    def addInPlace(self, acc1, acc2):
        acc1.extend(acc2)
        return acc1

# %%
def file_read1(line):
    global list1 # Required otherwise the next line will fail
    list1 += [{"line":line}]
    return line

# %%
# (word, [(did,freq,tfidf), ...])
# We easily obtain idf as 1/len(postinglist_tf)
# idf = 1/len(postinglist_tf)
 
result = sc.accumulator([], ListParam())

def tfidf(term, x):
  df = len(list(x))
  l = []
  global result 
  for t in x:
    l.append((t[0],t[1],t[2]/df))
    result += [{"doc":t[0], "term":term, "score":t[2]/df}]
  return l

# creating RDD
word_postinglist_freq_tfidf = word_postinglist_freq_tf.map(lambda x: (x[0],tfidf(x[0],x[1])))

# %% [markdown]
# ***Create RDD of (did,(freq,tfidf)) ***

# %%
# Now, we would like to obtain the magnitude of each doc.
# First, produce (did, (freq,tfidf)) for each word of doc did; 
# We do don't need the word itself, just its (freq,tfidf). 
# Then, do reduceByKey on these tuples and obtain maxfreq and 
# magnitude (squared) for each document. 

# RDD of (did,(freq,tfidf)) tuples

# creating RDD
did_freq_tfidfsq_rdd = word_postinglist_freq_tfidf.flatMap(lambda x: x[1]).map(lambda x: (x[0],(x[1],x[2]**2)))

# Produce (did,(maxf,magnitudesq))
# creating RDD
doc_maxf_mag = did_freq_tfidfsq_rdd.reduceByKey(lambda x,y:(max(x[0],y[0]),x[1]+y[1]))

# %%
827387803), (364, 9, 0.002848101265822785), (5172, 2, 0.0009041591320072332), (9171, 5, 0.0015822784810126582), (18709, 1, 0.0005274261603375527), (14896, 1, 0.0015822784810126582), (5462, 4, 0.002531645569620253), (10728, 1, 0.0007911392405063291), (8625, 2, 0.0012658227848101266), (16851, 1, 0.0004520795660036166), (12884, 3, 0.0031645569620253164), (13421, 4, 0.0031645569620253164), (16494, 1, 0.0007911392405063291), (7259, 3, 0.0023734177215189874), (15622, 1, 0.00039556962025316455), (14149, 1, 0.0010548523206751054), (2185, 1, 0.0015822784810126582), (2753, 2, 0.0015822784810126582), (17276, 1, 0.0007911392405063291), (14762, 1, 0.0006329113924050633), (6972, 2, 0.002109704641350211), (10936, 1, 0.0004520795660036166), (6570, 1, 0.0010548523206751054), (14992, 1, 0.0015822784810126582), (7032, 3, 0.0015822784810126582), (4078, 4, 0.0011507479861910242), (5424, 3, 0.0018987341772151898), (18006, 4, 0.002109704641350211), (11221, 3, 0.0015822784810126582), (5318, 2, 0.0005753739930955121), (13487, 1, 0.0006329113924050633), (17382, 1, 0.000395569620253 ...
# 21351 inv_idx/part-00000
# 21188 inv_idx/part-00001
# 42539 /content/drive/My Drive/inv_idx.txt

# %%
# !ls -lrt doc_mag
# !head doc_mag/part-00000
# !wc -l doc_mag/part-00000
# !wc -l doc_mag/part-00001
# !cat doc_mag/part-00000 doc_mag/part-00001 > /content/drive/My\ Drive/doc_mag.txt
# !wc -l /content/drive/My\ Drive/doc_mag.txt
# Out:
# total 636
# -rw-r--r-- 1 root root 324258 Apr  3 05:59 part-00001
# -rw-r--r-- 1 root root 323297 Apr  3 05:59 part-00000
# -rw-r--r-- 1 root root      0 Apr  3 05:59 _SUCCESS
# (16050, (3, 0.019505547637100547))
# (13228, (3, 0.05137016690348846))
# (15060, (4, 0.10386443840740586))
# (14950, (7, 0.22499457204331003))
# (15210, (5, 0.10864092200016229))
# (16480, (6, 0.028216833442731896))
# (14264, (3, 0.009554588500264439))
# (15320, (3, 0.000993183308447241))
# (13986, (2, 0.0002859740790185993))
# (15398, (4, 0.002872860074093733))
# 9500 doc_mag/part-00000
# 9526 doc_mag/part-00001
# 19026 /content/drive/My Drive/doc_mag.txt

# %% [markdown]
# **2.Create database tables for storing the inverted index**
#
# **Create database **

# %%
import sqlite3
# connect database
conn = sqlite3.connect('Database.db')
print('Opened database successfully.');
c = conn.cursor()
c.execute('''DROP TABLE IF EXISTS postings ''')
c.execute(''' 
        CREATE TABLE IF NOT EXISTS postings
       (word VARCHAR(100) PRIMARY KEY     ,
       postinglist_freq_tfidf TEXT       ,
     
       
       REAL);''')
c.execute('''DROP TABLE IF EXISTS docmag ''')
c.execute(''' 
        CREATE TABLE IF NOT EXISTS docmag
       (docid INT PRIMARY KEY     NOT NULL,
       maxf INT     NOT NULL,
       mag FLOAT
      
       REAL);''')
print('Table created successfully.');
conn.commit()
conn.close()
# Out:
# Opened database successfully.
# Table created successfully.

# %%
# store data to database

conn = sqlite3.connect('Database.db')
print('Opened database successfully.');
c = conn.cursor()

# delete content in database

sql_delete = """ DELETE FROM docmag"""
c.execute(sql_delete)

sql_delete = """ DELETE FROM postings"""
c.execute(sql_delete)


# look up content in database

sql_look = """ SELECT * FROM postings where word = 'jun'"""
c.execute(sql_look)
print(c.fetchall())


# insert data to database

with open("/content/drive/My Drive/doc_mag.txt") as f1:

    f11 = f1.readlines()

for x in f11:
  
   x.strip()
   x = re.findall(r'\d+\.?\d*', x)
   
   sql = """insert into docmag(docid,maxf,mag) values (?,?,?)"""
   c.execute(sql,[x[0],x[1],x[2]])

 
with open("/content/drive/My Drive/inv_idx.txt") as f2:   

    f22 = f2.readlines()
# first two columns 

for x in f22:
   x.strip()
   y = re.findall(r'\w+', x)
   y[0] = str(y[0])
   y[1] = str(y[1:])
   print(y[0]) 

   sql_1 = """insert into postings(word,postinglist_freq_tfidf) values (?,?)"""
   
   c.execute(sql_1,[y[0],y[1]])
 
conn.commit()
print('Records created successfully.');
conn.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# redbook
# ponderosa
# wpm
# superconductor
# coradian
# biosonics
# rune
# squander
# contradiction
# unreasonably
# unjustifiably
# invigorated
# accomodation
# suscription
# leblanc
# vermillion
# perwira
# phb
# tlarf
# reprogram
# reprograms
# doorley
# roylaties
# weirick
# stufflebeam
# vandalise
# kml
# upgradable
# fco
# versados
# filtertek
# machold
# pfeizer
# irv
# goss
# cpwr
# gti
# consul
# flotations
# pretend
# manoeuvres
# irrelevant
# pitted
# accompany
# inititally
# furnas
# centrais
# camilo
# votinmg
# eclipse
# bangor
# defaulted
# crporation
# races
# extinct
# uncontroversial
# pal
# sql
# wasatch
# terrier
# frampton
# isis
# esd
# seaborn
# arrangment
# sevices
# cerprobe
# crpb
# tarzell
# euphoric
# retrenchment
# zapf
# reassessed
# prise
# dikb
# airbags
# occupant
# spco
# aggressitvely
# fgi
# productvitiy
# cfs
# comapny
# financiera
# nf
# sparebanken
# waccamaw
# surfside
# bgph
# offerred
# cryodynamics
# roma
# aver
# twinjet
# bewtween
# seals
# multimarket
# brophy
# fraudalent
# suiker
# nza
# buttrose
# decipher
# wciin
# confronting
# junko
# renard
# particle
# reagent
# ovonic
# spacecraft
# ener
# sitter
# asca
# workloads
# determinations
# mics
# synchronous
# alledged
# adjustm
# fidelilty
# mex
# seedman
# festivities
# reversers
# sla
# stiffened
# eurodeposit
# discernible
# calmly
# bitten
# gtv
# laux
# vehemently
# misallocations
# ikng
# houmes
# fecom
# wasa
# europeiske
# reiseforsikring
# rejseforsikrings
# misstate
# illusory
# criticising
# gdps
# unsaturated
# weintraub
# cacoa
# tailored
# monopolised
# lubricants
# hierarchy
# bedevil
# sbending
# oks
# cpy
# landings
# welbac
# rebutts
# rebutted
# baur
# switchboard
# bauer
# readmission
# dnp
# northview
# enetertainment
# zinn
# hoses
# daning
# yangtse
# gms
# misco
# bengal
# poates
# redevelopment
# lai
# lohn
# ciots
# capitaine
# berthed
# nvis
# hermes
# undervalues
# devlopment
# tinkered
# alleviation
# ramdas
# synchronising
# briam
# westmoreland
# lincke
# golfs
# downpours
# titre
# emeryville
# immunex
# imnx
# remissions
# melanomas
# rectum
# observations
# immunuotherapy
# whitbread
# champagne
# benedictine
# miracles
# exaggeration
# blinkered
# monetaire
# luxembourgeois
# rebook
# reeboks
# counterfeits
# fakes
# leonhard
# gleske
# rested
# highveld
# handelsraad
# cornfeedmeal
# chd
# trash
# artisan
# ecusta
# pisgah
# doemstic
# disinfectant
# boudewijn
# ittersum
# westerterp
# roaring
# inordinate
# surmised
# acclerated
# marches
# hides
# manoogian
# harbert
# expo
# spilt
# costain
# coscan
# carena
# mullikin
# winchell
# multilaterally
# pasar
# deogracias
# leyte
# clda
# prem
# prachuab
# suntharangun
# wobbly
# cohesive
# bnbga
# bbusx
# kazuya
# kumura
# jbri
# jcra
# gasekt
# coba
# myraid
# ngen
# flum
# saltzer
# brightest
# nowak
# sytems
# mclucas
# greengrass
# transwestern
# ogren
# nabiscorjrto
# writ
# castlegar
# bridgewater
# peritoneal
# garza
# singling
# lister
# vhi
# circulars
# frees
# fleetflt
# norstarnor
# bankholding
# laud
# libra
# townesend
# lomax
# personalities
# janusz
# kaczurba
# pap
# moral
# baka
# inofrmation
# chariot
# cgr
# consoles
# ccs
# perioods
# pleasure
# yonne
# touristique
# salesd
# tetsuya
# dezuka
# chiyojima
# susin
# somphol
# kron
# consuemr
# griscom
# wezniak
# weznkiak
# possesses
# alkso
# bekaert
# affadavit
# interlink
# hoenemeyer
# soquem
# cazenove
# androscoggin
# cleaver
# eclairage
# sapula
# sequester
# confessions
# beddome
# sewers
# redefinition
# personalize
# sahara
# denmam
# herke
# sii
# mpany
# pohlad
# consideer
# boisseau
# telecontrol
# bolts
# lids
# cji
# cjiia
# selby
# retribution
# unamortized
# esquire
# technicalities
# seafirst
# fourths
# chryslerc
# caravan
# ramaphosa
# hispanic
# ouststanding
# jovial
# conglommerate
# callicoon
# ownes
# ownens
# priya
# ranjan
# dasmunsi
# paise
# sundstrand
# sns
# developoment
# sondey
# nioc
# envirosure
# classed
# ilto
# lyphomedlmed
# fujisawa
# duction
# nautical
# offeing
# feca
# cptla
# ide
# mahon
# verifying
# stempel
# grindlays
# pla
# robyn
# leibowitz
# liebowitz
# vanuatu
# hosposable
# groove
# unhelpful
# engerix
# frigitemp
# overexpended
# sober
# biden
# leyland
# counterproposals
# hylbert
# mentz
# lser
# aquisitions
# extradited
# cutout
# aztec
# nonproductive
# konishi
# uchiyama
# keiji
# tsuda
# detonator
# ojapanese
# japanse
# fsa
# ringside
# shevardnaze
# omer
# shaalan
# productively
# wam
# procassini
# susq
# cutthroat
# greenstein
# mackes
# cj
# santow
# anemic
# rli
# lynn
# obligator
# diverge
# kaczura
# zloty
# restores
# crldacquires
# fsla
# fourtou
# microdyme
# careercom
# crcm
# rosenfeld
# sunf
# bulgarian
# cypsa
# prim
# primages
# cvg
# sidor
# interalumina
# alcasa
# unicoa
# mailemcac
# nzym
# irreconcilable
# sitwell
# tunas
# rationed
# gorw
# sybron
# fortsmann
# catto
# seelig
# creditweek
# yfc
# talbot
# logs
# sunyou
# nssx
# strongpoint
# ons
# zzzz
# mizel
# compri
# accor
# sdame
# westwego
# bunge
# elmo
# predergast
# competiton
# craving
# hooking
# liss
# cooperativa
# harrosh
# handwritten
# betheleham
# ompany
# rinderpest
# lethal
# atoka
# athe
# coesfeld
# schallplattentruhe
# kommanditgesellschaft
# sdsb
# sett
# ortoli
# crd
# oneplus
# earle
# kawasumi
# shizuoka
# hatsuho
# narita
# tahashi
# insurable
# reinsure
# stcm
# stirling
# brunswig
# calmatczm
# extention
# nelect
# injects
# excelan
# qassimi
# braodway
# vlvl
# gilman
# ncreases
# hank
# yumyc
# unconstructive
# dmn
# unbudgeted
# blizzards
# piling
# paralyzing
# lampert
# competive
# wilms
# treuhand
# acquittal
# lamentable
# referrred
# brettenham
# qazi
# alimullah
# endowed
# avian
# nueutrogena
# ngna
# bearers
# bioreactor
# unindentified
# comprehensively
# aversion
# kraljevo
# ronc
# chelmsford
# sctc
# tuition
# thwarting
# somatotropin
# reafforestation
# mtly
# bogert
# bogo
# boget
# tymnet
# gramme
# aginst
# limb
# subordainted
# toot
# stereos
# radiocassettes
# unrepresentative
# battled
# dlp
# galleries
# clustering
# invariably
# bavaria
# suppositions
# undeground
# mounds
# wealthier
# feeble
# resonably
# sycip
# hdpe
# honan
# hangyang
# typewriter
# vv
# hoosiers
# distributrion
# nigh
# punitively
# overflowed
# abha
# wacoal
# uhco
# predepreciation
# reichert
# reichart
# medal
# presences
# stutz
# gwd
# marx
# tohe
# jmed
# extensification
# vinegrowers
# pointless
# progam
# bhamy
# dubin
# mosely
# silve
# poking
# penchent
# stategies
# sheaf
# superintendency
# cambio
# muggia
# bartering
# illustrating
# pmwi
# lantau
# goerdeler
# gtam
# ambank
# lacy
# spicer
# dissuaded
# illr
# clri
# balancers
# astride
# unsightly
# schuler
# deterrence
# appraoch
# warlike
# jedec
# schc
# wplvotes
# raycomm
# spiridellis
# gaurantee
# opp
# ranches
# forfieted
# ols
# unscathed
# thunderstorm
# fruiting
# profitt
# albanian
# kosovo
# bosnia
# spillman
# otaining
# hkme
# surrenderred
# deflate
# permeate
# inexorably
# ascribed
# taihei
# kroner
# coupler
# garlem
# ound
# sund
# ryal
# tsukuba
# communiques
# mosar
# badger
# dedramatise
# bsl
# liberte
# transmitting
# vogt
# telephonques
# addressograph
# farrington
# painewebbber
# westerners
# veers
# marcheschi
# kaysersberg
# eliminations
# labrecque
# associatioon
# dorsey
# dsy
# psli
# aece
# ruben
# mettler
# amty
# noakes
# commercialise
# thermophotovoltaic
# tpv
# wyle
# wyl
# chandler
# mftg
# bennigan
# ale
# despositors
# omnilab
# hndh
# shrt
# comfotrably
# spk
# fsx
# dodging
# altitudes
# penner
# distrust
# payday
# sorbents
# separte
# bevis
# scarred
# hearst
# chronicle
# laredo
# intelligencer
# javett
# luthie
# frog
# heldor
# subcontrators
# mulifunction
# choosen
# paramilitary
# reinosa
# telkom
# bilson
# negatiations
# powercise
# comission
# rosenthal
# telkon
# phxa
# znat
# nin
# uysed
# riddell
# equilink
# guillevin
# dibona
# empa
# sysa
# toiletry
# conformance
# crowell
# predominated
# accion
# democratica
# guss
# danziger
# noell
# enacts
# tcbc
# shiviyacu
# dirve
# nacsim
# stanwell
# barricaded
# sportscene
# soothes
# soothed
# uncouple
# siebel
# almadine
# winery
# madera
# farmington
# smashing
# bloodstained
# bayonet
# collaborated
# swindling
# fter
# narly
# sou
# becord
# beween
# grapples
# antagonise
# kate
# intelogic
# xyzs
# xzag
# xzap
# xyzq
# headlund
# paciofic
# recoton
# rcot
# huntingdon
# hrcly
# taiyo
# bamberger
# unip
# remodelling
# glasgow
# rihl
# tca
# cures
# laons
# poggi
# rosskopf
# rapp
# foreman
# overlaid
# slaner
# thrufax
# triplett
# seetransport
# mcl
# pharmacists
# dryer
# adna
# elmira
# asbi
# alfco
# albani
# absolves
# denting
# geosystems
# bandar
# abbas
# atvc
# deteriorates
# fringes
# reverted
# satcom
# combatant
# lnce
# jmbrs
# hornet
# landry
# redlake
# aritech
# arit
# adt
# frashier
# battleships
# lndh
# toxicological
# coinage
# ndsn
# bhopal
# deo
# carme
# macke
# stiffening
# minneopolis
# whack
# amev
# credibly
# postion
# wr
# infective
# investming
# detectible
# demonstrator
# contours
# scaling
# experieincing
# atwell
# newgotiated
# cashiers
# lfbr
# dozing
# girozcentrale
# epsc
# toth
# illiquid
# huber
# combuster
# chlorinated
# cortes
# estable
# defamatory
# broadcasts
# pharm
# pharmacology
# dulbin
# unibancorp
# ubcp
# discoverd
# crystals
# conductive
# througout
# actitivities
# bargained
# specal
# reprogrammed
# ellus
# riased
# mikhael
# jnauary
# einbender
# photosensitive
# dislocating
# sms
# proforma
# luerssen
# luxt
# revives
# configurations
# mocroprocessor
# palette
# crimped
# shci
# financialifg
# citadel
# silently
# fictitious
# acccounts
# meguerditch
# antananarivo
# gillet
# waga
# wjw
# witi
# kcst
# wsbk
# fixings
# pohlman
# electrohydraulic
# kabel
# lithium
# chlorosulphonic
# krummrich
# chlorosulfonic
# nlgt
# imd
# subordianted
# synchronization
# lawrenceburg
# mortages
# arenson
# pdq
# pipelline
# corpses
# bracho
# cayambe
# tmexf
# hurc
# dilligence
# moosburg
# sidewalk
# jammed
# sharehoilders
# bawl
# ti
# tigl
# boardmember
# baldridge
# hydropower
# scocozza
# andewelt
# kidston
# det
# oestasiatiske
# pulmonary
# unpatented
# tanghe
# conforms
# unassumed
# glenmede
# erba
# silvercrest
# shipbroker
# houlder
# thundershower
# bost
# cmh
# bhpg
# strengthed
# helmerich
# servant
# convern
# mauritania
# nonearning
# surf
# mmuc
# autorama
# insignia
# techpro
# theday
# hinsdale
# pkps
# jeps
# nail
# reintegration
# prearranged
# maree
# khor
# fakkan
# modifies
# angela
# donny
# freighters
# googel
# sisti
# pasb
# parlex
# kasier
# byproduct
# revelations
# wager
# weritedown
# csm
# csms
# rpk
# lilley
# qth
# mhga
# spectrometry
# sciex
# contraband
# willemijn
# compilation
# grootvlei
# gilardi
# anzali
# nowshahr
# neka
# jolfa
# squatter
# exasperated
# dwight
# evangelist
# moon
# alcoholism
# anguilla
# gulity
# csbm
# exams
# inexorable
# subduing
# uncompetitively
# visionary
# suppports
# stuffed
# develpoing
# diarrheal
# toxins
# repayers
# wbms
# slab
# equalling
# iafmm
# sardine
# doorne
# manifest
# fairey
# doulton
# genossenschaftbank
# contributary
# taro
# tarof
# wade
# caro
# whitfield
# ficticious
# polyphenyls
# francx
# efi
# hma
# wesbanco
# sissonville
# tradestar
# tirr
# geary
# passu
# cortronic
# ctrn
# isthmus
# imitates
# imitated
# benylin
# spw
# motorsgm
# fiif
# overlaps
# ludena
# fianna
# particularily
# availed
# txln
# pke
# colville
# fernald
# reincorpoation
# mocrosoft
# receiveing
# elecetric
# schleede
# pulverized
# decrements
# breakage
# remisiers
# remisier
# workplace
# tn
# ine
# claremont
# cirigliano
# evolve
# shsb
# mothball
# garo
# armen
# smli
# aquires
# dbms
# shibosai
# brenton
# bingo
# sago
# halvorsen
# fostoria
# willie
# lyatu
# asphalt
# mastertronic
# mpuc
# adaptor
# nano
# marxism
# speyer
# iffezheim
# recker
# metrologie
# stepan
# scl
# meredith
# ssi
# interpreter
# bdl
# racquet
# awk
# corolla
# mielke
# coldwater
# respite
# ribi
# immunochem
# monophosphoryl
# malignant
# instigate
# allaying
# laudable
# polite
# microcosm
# blankart
# lifeblood
# colbert
# coyman
# knell
# conscience
# blunders
# commonstock
# chemotherapy
# nda
# labarbera
# shanahan
# maintenenace
# hx
# woirth
# tegucigalpa
# piasters
# akhbar
# unreseved
# flourishes
# pollinates
# mixing
# trimedia
# siehl
# preeminence
# idcc
# anititrust
# wiener
# punte
# scrp
# flavour
# ix
# pswa
# wringing
# pantent
# elastin
# annul
# wiegand
# gaedicke
# scrutinize
# publicizing
# arundel
# wester
# tampico
# shinc
# commanders
# subhy
# crrs
# wyona
# reuber
# pondering
# mtsr
# handelsgesmbh
# mcdoulett
# hagopian
# fitb
# flyfaire
# shefra
# ironclad
# csba
# exlcudes
# htwn
# miln
# verda
# nets
# cascading
# kosters
# flappers
# shoeshine
# hysterical
# clamored
# discrimatory
# broadcaster
# stank
# gustave
# tnt
# officlals
# lori
# lrc
# adalbert
# foliage
# kumagai
# gumi
# mcginnis
# stiritz
# mokg
# stlhas
# svicc
# agonizing
# obliquely
# nsx
# silvertown
# weighhouse
# maputo
# skirmish
# bvmg
# bhwg
# industriekreditbank
# hein
# viatech
# vtk
# landell
# redistributed
# mylx
# integrators
# ryle
# idic
# hai
# prtax
# undetailed
# maghreb
# kot
# addu
# tdi
# rosie
# deirdre
# nucleic
# pnu
# katz
# maccia
# sull
# palay
# hectarage
# nonthrift
# wojciech
# jaruzelski
# koziol
# paducah
# spartechsptn
# hermetronics
# hermetic
# vipont
# viadent
# gums
# carmaking
# aerodynamic
# governemnt
# watta
# gosper
# meagre
# hewitt
# sisson
# baluch
# app
# obci
# innopac
# rosenkranz
# rsl
# reconciling
# westco
# lafarege
# laf
# sentuc
# porxpan
# chill
# hostetler
# erekson
# kacek
# depite
# hermdbs
# friedrichflick
# societes
# keeper
# noml
# latacunga
# sennen
# lazo
# inserting
# safekeeping
# cubes
# paralax
# stibnite
# hemodynamics
# acqure
# negotiaitons
# incrased
# janaury
# grantors
# logicals
# purchse
# platinova
# cinemas
# theter
# milledgeville
# accorded
# wjtc
# uhf
# ladf
# sab
# technologiescih
# wenatchee
# inyo
# chromite
# inlet
# devilish
# impoverish
# polysaturated
# intercrop
# segregate
# appendix
# cartier
# conduits
# existent
# abram
# cavarellino
# gofrank
# parrillo
# sltm
# inl
# burnet
# predicate
# blackman
# uhler
# intex
# subsdiaries
# priveleged
# weloming
# explainable
# inconclusively
# wayfoong
# underwtriting
# viurs
# vmx
# vmxi
# scheduler
# keener
# breakers
# tsia
# shipbreaker
# bula
# premission
# assocates
# poc
# remuneration
# reinitiate
# strep
# rudimentary
# custodians
# krugerrands
# summe
# absences
# dance
# tomenson
# kicking
# ellmann
# herstal
# knitted
# adventist
# outbidhell
# informatics
# caobisco
# terephthalic
# wilbur
# sbm
# wjye
# mclendon
# chjief
# champagnes
# brandies
# cellars
# turistiche
# sibeka
# chili
# mccrann
# atlc
# masbate
# estimation
# restarts
# sihler
# playmate
# trreasury
# boardwalk
# waged
# dansk
# shedding
# atmoscan
# wafer
# konover
# gampel
# bevi
# pneumatics
# linares
# trieste
# negotitations
# patt
# abolishment
# yothin
# bfit
# punctuated
# kamchorn
# sathirakul
# maruay
# hfga
# creditworthy
# unawares
# screg
# gmf
# mondiale
# bountiful
# aweke
# aynalem
# attaining
# wello
# cexx
# contending
# alfonse
# omco
# dore
# tuolumne
# asamoah
# informational
# businessmate
# uwr
# macedon
# refelected
# fmbc
# twisting
# wbt
# earley
# cattlemens
# kuznetsov
# lucinda
# produer
# piosec
# followin
# bachmann
# sussman
# bw
# biotec
# sait
# iep
# securties
# narrowcast
# uniclob
# deutschmark
# biv
# ailments
# alzheimer
# executes
# softvisions
# snla
# infrared
# carrageenan
# seaplant
# thicken
# paucity
# arscc
# bachem
# sholes
# inexact
# chiron
# improbability
# mathieu
# neuflize
# mallet
# sni
# wpb
# todays
# kamloops
# dilligance
# wopuld
# audiovisual
# thmp
# garcin
# supervisor
# tempos
# disastrously
# andr
# coincidental
# sasles
# wj
# amplifiers
# nps
# digoxin
# betweeen
# cornea
# lubricate
# fyodorov
# corneal
# starrex
# dunkin
# donuts
# amtron
# mum
# cayb
# ltek
# reevaluating
# cavh
# lasg
# requiresd
# stateement
# bent
# backlogs
# miny
# hambrechit
# granulocyte
# macrophage
# qet
# phph
# mtec
# nonaccural
# stepanian
# cdo
# pontikes
# printronix
# ptnx
# ncso
# interconnected
# dbas
# bellet
# vse
# booths
# viola
# meierfeld
# portugese
# flfe
# disinterested
# alderman
# kasgeld
# visas
# nissen
# gemma
# wi
# springing
# imponderables
# sticht
# tylee
# maxisaver
# payn
# grantes
# orginially
# articulation
# ambassadorial
# novia
# honk
# moonachie
# inning
# dmot
# charade
# stearn
# conergic
# livingston
# fwch
# pdi
# schult
# montgomey
# volkskas
# hinging
# contradictions
# gmc
# reseed
# demetree
# changeoover
# oakville
# nameplates
# revenge
# lcb
# joists
# rack
# mitigating
# mayp
# ang
# hfsl
# howen
# mahdi
# ggz
# hg
# vernors
# moc
# aribrageurs
# birnbaum
# debtentures
# republicbankcorp
# eci
# almi
# beause
# pensioner
# operatorships
# smoerbukk
# barents
# fina
# fdos
# distiller
# saq
# qnb
# khalid
# ahli
# retrenched
# qatari
# farquharson
# salvino
# yi
# gauged
# corrupted
# ramie
# linen
# scalpel
# retorted
# devalues
# shouls
# gunther
# blenkarn
# cassidy
# lebow
# efthymia
# fokida
# pfr
# deutschemark
# schelsinger
# timex
# tissot
# siren
# howl
# howling
# newshour
# abover
# geogia
# unitek
# orthodontic
# monrovia
# scixf
# cityquest
# ferroviarias
# itil
# humaid
# crafting
# tipping
# mauro
# robustness
# epi
# worsens
# converging
# braatz
# elx
# rebelling
# loneliness
# zairean
# ravages
# zhujiang
# turnberry
# kyle
# jackaman
# amrc
# kyats
# possis
# poss
# ilyushin
# vfsc
# intendend
# freeboard
# rainwawater
# goulds
# guld
# unsurpassed
# superiors
# harg
# kduwi
# disequilibrium
# tnta
# ashford
# conspire
# handsome
# pakcage
# sumptuous
# elation
# develoed
# anmessages
# kuppenheimer
# briar
# screrwworms
# gottsegen
# ramsden
# ciro
# ciri
# ambac
# substnatial
# contination
# rampura
# agucha
# chaneriya
# telemedia
# editiion
# korkman
# russelsteel
# atassi
# conventions
# broomall
# eqica
# sysm
# staalfabrieken
# affilated
# schiffer
# baty
# lwr
# maier
# coned
# eldctric
# heartening
# futjitsu
# subcategories
# overreacts
# comprehend
# hunch
# glad
# kunthon
# olarn
# chaipravat
# somboon
# segmented
# excuses
# ands
# buts
# mutuality
# attests
# curent
# watertown
# essi
# reawakened
# dearth
# teq
# gggg
# irsnu
# irsnw
# launhces
# dtsi
# renta
# inmobiliaria
# interpart
# giancarlo
# elstree
# farwest
# ffws
# quarterrofit
# catagory
# sinister
# manufacturters
# repatriated
# romney
# dynamited
# reil
# victa
# shearing
# aluvic
# revel
# arjen
# indqa
# bendix
# harilaos
# evros
# dounas
# cpsapayout
# formatter
# changer
# milliseconds
# mouinted
# arno
# undiluted
# karasmasoglu
# clairify
# pubilic
# exotic
# goliath
# kkk
# pkoh
# sanpao
# rfbk
# idn
# itd
# creaking
# keigger
# maxiumum
# deporsitary
# overplayed
# aminoil
# farmout
# belive
# taggart
# oft
# wallet
# enforceable
# fsc
# finanancial
# bombardier
# salesmen
# greenland
# scorned
# kasch
# ctec
# thermoset
# fowl
# newscope
# erroding
# exchangeing
# extinguishable
# penzoil
# retraints
# frighten
# continuuing
# hardwick
# maricopa
# cantrade
# convenent
# varitronics
# coverig
# previoius
# berard
# epithermal
# ahr
# publicsoft
# empi
# internationalerc
# fiia
# Records created successfully.

# %% [markdown]
# **Implement the keyword search functionality.**
# **Implement result ranking using the TF-IDF measure.**
# **Implement a simple interface for giving keyword queries and showing results.**
#
# Search(Query, TopN): TopN_Documents

# %%
def tokenize(htmltext):
  cleantext = BeautifulSoup(htmltext).get_text().lower()

  #returning result
  tokenizedText = re.findall(r"\b[a-z]+\b",cleantext)
  filteredToken = [w for w in tokenizedText if not w in stop_words]
  tokenCnt = Counter(filteredToken)
  return tokenizedText

# %% [markdown]
# **Cosine Similarity Ranking based on TF-IDF **

# %%
import math
import re
def get_cosine(vec1, vec2):
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])

    sum1 = sum([vec1[x] ** 2 for x in list(vec1.keys())])
    sum2 = sum([vec2[x] ** 2 for x in list(vec2.keys())])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)

    if not denominator:
        return 0.0
    else:
        return float(numerator) / denominator

# %%
tfidf_RDD = sc.parallelize(result.value).map(lambda x: (x['term'],(x['doc'],x['score']) )) # the corpus with tfidf scores

def search(query):
  tokens = sc.parallelize(tokenize(query.value)).map(lambda x: (x,1) ).collectAsMap()
  bcTokens = sc.broadcast(tokens)
  
  joined_tfidf = tfidf_RDD.map(lambda k: (k[0],bcTokens.value.get(k[0],'-'),k[1])).filter(lambda x: x[1] != '-' )
  new_rdd = joined_tfidf.countByKey()
  cosine_score = get_cosine(tokens,new_rdd)
  scount = joined_tfidf.map(lambda a: a[2]).aggregateByKey((0,0),
  (lambda acc, value: (acc[0] +value,acc[1]+1)),
  (lambda acc1,acc2: (acc1[0]+acc2[0],acc1[1]+acc2[1])) )
  
  scores = scount.map(lambda k: ( k[1][0]*k[1][1]/len(tokens), k[0]) ).top(3)
 
  if len(scores) == 1:
    print('The most relevant HTML ID is:', scores[0][1])
  elif len(scores) == 2:
    print('The most relevant HTML ID is:', scores[0][1])
    print('The 2nd most relevant HTML ID is:', scores[1][1])
  elif len(scores) >= 3:
    print('The most relevant HTML ID is:', scores[0][1])
    print('The 2nd most relevant HTML ID is:', scores[1][1])
    print('The 3rd most relevant HTML ID is:', scores[2][1])
  elif len(scores) == 0:
    print('String not found')

  return scores

# %%
# Text User Interface

import ipywidgets as widgets
from IPython.display import display
print("After putting in a word, hit enter at least AFTER 3 seconds. It may take time for the system to load.")
print("Allow at least 3 seconds between different word search. Your computer may be fast, but just in case.")
print("Have fun and thank you!")
print("Input is case sensitive.")
text = widgets.Text()
display(text)

text.on_submit(search)
# Out:
# After putting in a word, hit enter at least AFTER 3 seconds. It may take time for the system to load.
# Allow at least 3 seconds between different word search. Your computer may be fast, but just in case.
# Have fun and thank you!
# Input is case sensitive.
# Text(value='')
# The most relevant HTML ID is: 11487
# The 2nd most relevant HTML ID is: 18359
# The 3rd most relevant HTML ID is: 1899
